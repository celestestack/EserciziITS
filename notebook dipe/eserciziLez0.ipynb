# %% [markdown]
# # Esercizi Lezione 0

# %% [markdown]
# ## Esercizi Base
#
# ### 1. Dato un numero scrivere se è positivo, negativo o nullo

# %%
# Esercizio 1: Verificare se un numero è positivo, negativo o nullo
numero = float(input("Inserisci un numero: "))

if numero > 0:
    print("Il numero è positivo")
elif numero < 0:
    print("Il numero è negativo")
else:
    print("Il numero è nullo")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Esercizio 1: Verificare se un numero è positivo, negativo o nullo
# ----> 2 numero = float(input("Inserisci un numero: "))
#       4 if numero > 0:
#       5     print("Il numero è positivo")
#
# ValueError: could not convert string to float: 'j'

# %%
# Test dell'Esercizio 1 con valori predefiniti
def test_positivo_negativo_nullo(numero):
    if numero > 0:
        return "Il numero è positivo"
    elif numero < 0:
        return "Il numero è negativo"
    else:
        return "Il numero è nullo"

# Test con diversi valori
test_values = [5, -3, 0, 2.5, -1.2]
for val in test_values:
    risultato = test_positivo_negativo_nullo(val)
    print(f"Numero: {val} -> {risultato}")
# Out:
# Numero: 5 -> Il numero è positivo
# Numero: -3 -> Il numero è negativo
# Numero: 0 -> Il numero è nullo
# Numero: 2.5 -> Il numero è positivo
# Numero: -1.2 -> Il numero è negativo

# %% [markdown]
# ### 2. Dati due numeri, scrivere il maggiore (verificare anche se sono uguali)

# %%
# Esercizio 2: Trovare il maggiore tra due numeri
num1 = float(input("Inserisci il primo numero: "))
num2 = float(input("Inserisci il secondo numero: "))

if num1 > num2:
    print(f"Il maggiore è {num1}")
elif num2 > num1:
    print(f"Il maggiore è {num2}")
else:
    print("I due numeri sono uguali")
# Out:
# Il maggiore è 54.0

# %%
# Test dell'Esercizio 2 con valori predefiniti
def test_maggiore(num1, num2):
    if num1 > num2:
        return f"Il maggiore è {num1}"
    elif num2 > num1:
        return f"Il maggiore è {num2}"
    else:
        return "I due numeri sono uguali"

# Test con diversi valori
test_pairs = [(5, 3), (2, 8), (4, 4), (-1, -5), (0, 0)]
for n1, n2 in test_pairs:
    risultato = test_maggiore(n1, n2)
    print(f"Confronto {n1} e {n2}: {risultato}")
# Out:
# Confronto 5 e 3: Il maggiore è 5
# Confronto 2 e 8: Il maggiore è 8
# Confronto 4 e 4: I due numeri sono uguali
# Confronto -1 e -5: Il maggiore è -1
# Confronto 0 e 0: I due numeri sono uguali

# %% [markdown]
# ### 3. Dati due numeri scrivere il loro quoziente, se il divisore è diverso da 0 allora stampare la divisione altrimenti "impossibile" se il divisore = 0

# %%
# Esercizio 3: Calcolare il quoziente di due numeri
dividendo = float(input("Inserisci il dividendo: "))
divisore = float(input("Inserisci il divisore: "))

if divisore != 0:
    quoziente = dividendo / divisore
    print(f"Il quoziente è: {quoziente}")
else:
    print("Impossibile: divisione per zero!")
# Out:
# Il quoziente è: 1.2857142857142858

# %% [markdown]
# ### 4. Data la base e l'altezza di un triangolo, scrivere l'area

# %%
# Esercizio 4: Calcolare l'area di un triangolo
base = float(input("Inserisci la base del triangolo: "))
altezza = float(input("Inserisci l'altezza del triangolo: "))

area = (base * altezza) / 2
print(f"L'area del triangolo è: {area}")
# Out:
# L'area del triangolo è: 16.0

# %% [markdown]
# ## Esercizi con Cicli
#
# ### 5. Dati 10 numeri scrivere la loro somma, numeri inseriti ad ogni iterazione

# %%
# Esercizio 5: Somma di 10 numeri
somma = 0
for i in range(10):
    numero = float(input(f"Inserisci il numero {i+1}: "))
    somma += numero

print(f"La somma dei 10 numeri è: {somma}")
# Out:
# La somma dei 10 numeri è: 23290.0

# %% [markdown]
# ### 6. Dati n numeri scrivere il loro prodotto

# %%
# Esercizio 6: Prodotto di n numeri
n = int(input("Quanti numeri vuoi moltiplicare? "))
prodotto = 1

for i in range(n):
    numero = float(input(f"Inserisci il numero {i+1}: "))
    prodotto *= numero

print(f"Il prodotto dei {n} numeri è: {prodotto}")
# Out:
# Il prodotto dei 3 numeri è: 2117016.0

# %% [markdown]
# ### 7. Dato un numero scrivere se è multiplo di 10

# %%
# Esercizio 7: Verificare se un numero è multiplo di 10
numero = int(input("Inserisci un numero: "))

if numero % 10 == 0:
    print(f"{numero} è multiplo di 10")
else:
    print(f"{numero} non è multiplo di 10")
# Out:
# 4 non è multiplo di 10

# %% [markdown]
# ### 8. Dati 10 caratteri e un carattere c dire se c è uno dei caratteri inseriti

# %%
# Esercizio 8: Ricerca di un carattere in una lista
caratteri = []

# Inserimento di 10 caratteri
for i in range(10):
    char = input(f"Inserisci il carattere {i+1}: ")
    caratteri.append(char)

# Carattere da cercare
c = input("Inserisci il carattere da cercare: ")

if c in caratteri:
    print(f"Il carattere '{c}' è presente nella lista")
else:
    print(f"Il carattere '{c}' non è presente nella lista")
# Out:
# Il carattere '67' è presente nella lista

# %% [markdown]
# ### 9. Inserire n numeri diversi da 0 (0 per finire), contare quanti sono i numeri inseriti

# %%
# Esercizio 9: Contare numeri inseriti (diversi da 0)
count = 0

print("Inserisci numeri (0 per terminare):")
while True:
    numero = float(input("Numero: "))
    if numero == 0:
        break
    count += 1

print(f"Hai inserito {count} numeri")
# Out:
# Inserisci numeri (0 per terminare):
# Hai inserito 6 numeri

# %% [markdown]
# ### 10. Implementare una calcolatrice chiedendo all'utente di inserire i valori e l'operatore

# %%
# Esercizio 10: Calcolatrice semplice
num1 = float(input("Inserisci il primo numero: "))
operatore = input("Inserisci l'operatore (+, -, *, /): ")
num2 = float(input("Inserisci il secondo numero: "))

if operatore == "+":
    risultato = num1 + num2
elif operatore == "-":
    risultato = num1 - num2
elif operatore == "*":
    risultato = num1 * num2
elif operatore == "/":
    if num2 != 0:
        risultato = num1 / num2
    else:
        print("Errore: divisione per zero!")
        risultato = None
else:
    print("Operatore non valido!")
    risultato = None

if risultato is not None:
    print(f"Risultato: {num1} {operatore} {num2} = {risultato}")
# Out:
# Risultato: 65644.0 * 8.0 = 525152.0

# %% [markdown]
# ## Esercizi Avanzati
#
# ### 11. Scrivete un programma che chieda all'utente di indovinare una password, ma che dia al giocatore solamente 3 possibilità, fallite le quali il programma terminerà, stampando "È troppo complicato per voi"

# %%
# Esercizio 11: Gioco password con 3 tentativi
password_segreta = "python123"
tentativi = 3

for tentativo in range(tentativi):
    password_inserita = input(f"Tentativo {tentativo + 1}/3 - Inserisci la password: ")
    
    if password_inserita == password_segreta:
        print("Password corretta! Accesso consentito.")
        break
    else:
        if tentativo < tentativi - 1:
            print("Password errata. Riprova.")
        else:
            print("È troppo complicato per voi")
# Out:
# Password errata. Riprova.
# Password errata. Riprova.
# È troppo complicato per voi

# %% [markdown]
# ### 12. Scrivete un programma che chieda due numeri. Se la somma dei due numeri supera 100, stampate "Numero troppo grande"

# %%
# Esercizio 12: Controllo somma superiore a 100
num1 = float(input("Inserisci il primo numero: "))
num2 = float(input("Inserisci il secondo numero: "))

somma = num1 + num2

if somma > 100:
    print("Numero troppo grande")
else:
    print(f"La somma è {somma}")
# Out:
# La somma è 98.0

# %% [markdown]
# ### 13. Scrivete un programma che chieda all'utente il nome. Se viene inserito il vostro nome, il programma dovrà rispondere con un "Questo è un bel nome", se il nome inserito è Mario Rossi o Giuseppe Verdi il programma dovrà rispondere con una battuta ;) mentre in tutti gli altri casi l'output del programma sarà un semplice "Tu hai un bel nome!".

# %%
# Esercizio 13: Riconoscimento nomi
mio_nome = "Antonio"  # Sostituisci con il tuo nome
nome_inserito = input("Come ti chiami? ")

if nome_inserito.lower() == mio_nome.lower():
    print("Questo è un bel nome")
elif nome_inserito.lower() == "mario rossi":
    print("Ah, il classico nome da esempio! 😄")
elif nome_inserito.lower() == "giuseppe verdi":
    print("Come il famoso compositore! Sai suonare il pianoforte? 🎵")
else:
    print("Tu hai un bel nome!")
# Out:
# Tu hai un bel nome!

# %% [markdown]
# ## Esercizi con Funzioni
#
# ### 14. Riscrivete il programma 'area.py', definendo funzioni separate per l'area del quadrato, del rettangolo e del cerchio (3.14 * raggio**2). Il programma deve includere anche un'interfaccia a menu

# %%
# Esercizio 14: Calcolatore di aree con menu
import math

def area_quadrato(lato):
    """Calcola l'area del quadrato"""
    return lato ** 2

def area_rettangolo(base, altezza):
    """Calcola l'area del rettangolo"""
    return base * altezza

def area_cerchio(raggio):
    """Calcola l'area del cerchio"""
    return 3.14 * raggio ** 2

def menu_aree():
    """Menu per calcolare diverse aree"""
    while True:
        print("\n=== CALCOLATORE DI AREE ===")
        print("1. Area del quadrato")
        print("2. Area del rettangolo")
        print("3. Area del cerchio")
        print("4. Esci")
        
        scelta = input("Scegli un'opzione (1-4): ")
        
        if scelta == "1":
            lato = float(input("Inserisci il lato del quadrato: "))
            area = area_quadrato(lato)
            print(f"L'area del quadrato è: {area}")
            
        elif scelta == "2":
            base = float(input("Inserisci la base del rettangolo: "))
            altezza = float(input("Inserisci l'altezza del rettangolo: "))
            area = area_rettangolo(base, altezza)
            print(f"L'area del rettangolo è: {area}")
            
        elif scelta == "3":
            raggio = float(input("Inserisci il raggio del cerchio: "))
            area = area_cerchio(raggio)
            print(f"L'area del cerchio è: {area}")
            
        elif scelta == "4":
            print("Arrivederci!")
            break
            
        else:
            print("Opzione non valida!")

# Avvia il menu
menu_aree()
# Out:
# === CALCOLATORE DI AREE ===
# 1. Area del quadrato
# 2. Area del rettangolo
# 3. Area del cerchio
# 4. Esci
# L'area del rettangolo è: 5655.0
#
# === CALCOLATORE DI AREE ===
# 1. Area del quadrato
# 2. Area del rettangolo
# 3. Area del cerchio
# 4. Esci
# Arrivederci!

# %% [markdown]
# ### 15. Scrivere una funzione che dica se una parola è palindroma ("Anna", "SOS")

# %%
# Esercizio 15: Verificare se una parola è palindroma
def is_palindroma(parola):
    """Verifica se una parola è palindroma"""
    # Converte in minuscolo per confronto case-insensitive
    parola_pulita = parola.lower().replace(" ", "")
    
    # Confronta la parola con la sua versione invertita
    return parola_pulita == parola_pulita[::-1]

# Test della funzione
parole_test = ["Anna", "SOS", "radar", "ciao", "osso", "A man a plan a canal Panama"]

for parola in parole_test:
    if is_palindroma(parola):
        print(f"'{parola}' è palindroma")
    else:
        print(f"'{parola}' non è palindroma")

# Test interattivo
print("\n--- Test interattivo ---")
parola_utente = input("Inserisci una parola da verificare: ")
if is_palindroma(parola_utente):
    print(f"'{parola_utente}' è palindroma!")
else:
    print(f"'{parola_utente}' non è palindroma.")
# Out:
# 'Anna' è palindroma
# 'SOS' è palindroma
# 'radar' è palindroma
# 'ciao' non è palindroma
# 'osso' è palindroma
# 'A man a plan a canal Panama' è palindroma
#
# --- Test interattivo ---
# 'fdutkhvkjo' non è palindroma.

# %% [markdown]
# ## Esercizio Finale
#
# ### 16. Scrivere un programma Lunghezze che chiede all'utente di inserire una sequenza di stringhe e conclusa dalla stringa vuota, e poi stampa la somma delle lunghezze delle stringhe che iniziano con una lettera maiuscola. Per esempio, se si immettono le stringhe "Albero", "foglia", "Radici", "Ramo", "fiore" (e poi "" per finire), il programma stampa 16.

# %%
# Esercizio 16: Programma Lunghezze
def programma_lunghezze():
    """Calcola la somma delle lunghezze delle stringhe che iniziano con maiuscola"""
    somma_lunghezze = 0
    stringhe_maiuscole = []
    
    print("Inserisci stringhe (stringa vuota per terminare):")
    
    while True:
        stringa = input("Stringa: ")
        
        # Se la stringa è vuota, termina l'inserimento
        if stringa == "":
            break
            
        # Se la stringa inizia con maiuscola, aggiungila alla somma
        if stringa[0].isupper():
            somma_lunghezze += len(stringa)
            stringhe_maiuscole.append(stringa)
    
    print(f"\nStringhe che iniziano con maiuscola: {stringhe_maiuscole}")
    print(f"Somma delle lunghezze: {somma_lunghezze}")
    
    return somma_lunghezze

# Esecuzione del programma
risultato = programma_lunghezze()

# Test con esempio fornito
print("\n--- Test con esempio fornito ---")
stringhe_esempio = ["Albero", "foglia", "Radici", "Ramo", "fiore"]
somma_esempio = 0
stringhe_maiuscole_esempio = []

for stringa in stringhe_esempio:
    if stringa[0].isupper():
        somma_esempio += len(stringa)
        stringhe_maiuscole_esempio.append(stringa)
        
print(f"Stringhe esempio: {stringhe_esempio}")
print(f"Stringhe con maiuscola: {stringhe_maiuscole_esempio}")
print(f"Lunghezze: {[len(s) for s in stringhe_maiuscole_esempio]}")
print(f"Somma: {somma_esempio} (dovrebbe essere 16)")
# Out:
# Inserisci stringhe (stringa vuota per terminare):
#
# Stringhe che iniziano con maiuscola: []
# Somma delle lunghezze: 0
#
# --- Test con esempio fornito ---
# Stringhe esempio: ['Albero', 'foglia', 'Radici', 'Ramo', 'fiore']
# Stringhe con maiuscola: ['Albero', 'Radici', 'Ramo']
# Lunghezze: [6, 6, 4]
# Somma: 16 (dovrebbe essere 16)
